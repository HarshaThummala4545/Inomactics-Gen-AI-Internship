# %%
messages = [ "Hi","Welcome to the platform","OK"]
for i in messages:
  length = len(i)
  print(f"Messages: {i},Length: {length}")
  if(length > 10):
    print("Messages is too long")
# Out:
# Messages: Hi,Length: 2
# Messages: Welcome to the platform,Length: 23
# Messages is too long
# Messages: OK,Length: 2
