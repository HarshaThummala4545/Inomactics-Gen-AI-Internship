# %%
marks = [45,78,90,33,60]
Pass = 0;
Fail = 0;
for i in marks :
  if i  >= 50:
    Pass += 1
  else:
      Fail += 1
print("Total no.of Students :",len(marks))
print("Total Pass Marks :",Pass)
print("Total Fail Marks:",Fail)
# Out:
# Total no.of Students : 5
# Total Pass Marks : 3
# Total Fail Marks: 2
